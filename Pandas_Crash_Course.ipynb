# %% [markdown]
# ## Chapter 1:Getting & Knowing your Data

# %%
import pandas as pd

# %%
import pandas as pd

Employee_Dataset = pd.read_csv("Employee Dataset - TSV (1).txt", sep="\t")

Employee_Dataset.head()
# Out:
#   Employee Name  Age Last Working Day            Department      Education  \
# 0        Jitesh   41       31-12-9999              Training        Masters
# 1        Sanjit   49       31-12-9999                 Sales        Masters
# 2          John   37       31-12-9999                   R&D      Doctorate
# 3        Sandra   33       31-12-9999  Software Development  Undergraduate
# 4         Madhu   27       31-12-9999                   R&D        Masters
#
#    Gender Marital Status  Monthly Income  Years of Experience  \
# 0    Male         Single            5993                    8
# 1    Male        Married            5130                    1
# 2    Male         Single            2090                    6
# 3  Female        Married            2909                    1
# 4    Male        Married            3468                    9
#
#    Percent Salary Hike  Performance Rating
# 0                   11                   3
# 1                   23                   4
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '01_Python_programming', '02_Python_Libraries_Introduction', 'Employee Dataset - TSV (1).txt', 'employee_data.csv', 'Euro_2012_stats_TEAM.csv', 'new_employee_data.xlsx', 'Pandas_Crash_Course.ipynb', 'Python Data Structures.ipynb', 'Server.xlsx']

# %%
Employee_Dataset = pd.read_table("Employee Dataset - TSV (1).txt", sep="\t")

Employee_Dataset.head()
# Out:
#   Employee Name  Age Last Working Day            Department      Education  \
# 0        Jitesh   41       31-12-9999              Training        Masters
# 1        Sanjit   49       31-12-9999                 Sales        Masters
# 2          John   37       31-12-9999                   R&D      Doctorate
# 3        Sandra   33       31-12-9999  Software Development  Undergraduate
# 4         Madhu   27       31-12-9999                   R&D        Masters
#
#    Gender Marital Status  Monthly Income  Years of Experience  \
# 0    Male         Single            5993                    8
# 1    Male        Married            5130                    1
# 2    Male         Single            2090                    6
# 3  Female        Married            2909                    1
# 4    Male        Married            3468                    9
#
#    Percent Salary Hike  Performance Rating
# 0                   11                   3
# 1                   23                   4
# ...

# %% [markdown]
# ## 1.1 Perform Initial Analysis

# %%
#Function - ()
#Attribute

# %%
Employee_Dataset.shape
# Out:
# (25, 11)

# %% [markdown]
# #### Terminology Alert
#
# - Rows - Observations/Record
# - Column - Features/Parameters

# %%
Employee_Dataset.isnull().sum() #Chain of functions,Chain of commands
# Out:
# Employee Name          0
# Age                    0
# Last Working Day       0
# Department             0
# Education              0
# Gender                 1
# Marital Status         2
# Monthly Income         0
# Years of Experience    0
# Percent Salary Hike    0
# Performance Rating     0
# dtype: int64

# %%
Employee_Dataset.dtypes
# Out:
# Employee Name          object
# Age                     int64
# Last Working Day       object
# Department             object
# Education              object
# Gender                 object
# Marital Status         object
# Monthly Income          int64
# Years of Experience     int64
# Percent Salary Hike     int64
# Performance Rating      int64
# dtype: object

# %%
Employee_Dataset.describe(include ="all")
# Out:
#        Employee Name       Age Last Working Day            Department  \
# count             25  25.00000               25                    25
# unique            23       NaN                3                     5
# top             Adam       NaN       31-12-9999  Software Development
# freq               3       NaN               23                    13
# mean             NaN  35.08000              NaN                   NaN
# std              NaN   8.40595              NaN                   NaN
# min              NaN  22.00000              NaN                   NaN
# 25%              NaN  30.00000              NaN                   NaN
# 50%              NaN  34.00000              NaN                   NaN
# 75%              NaN  37.00000              NaN                   NaN
# max              NaN  59.00000              NaN                   NaN
#
#        Education Gender Marital Status  Monthly Income  Years of Experience  \
# ...

# %% [markdown]
# ## 1.2 Find Out The Monthly Income Of Employees

# %%
Employee_Dataset.nunique()
# Out:
# Employee Name          23
# Age                    18
# Last Working Day        3
# Department              5
# Education               3
# Gender                  2
# Marital Status          3
# Monthly Income         23
# Years of Experience     9
# Percent Salary Hike    12
# Performance Rating      2
# dtype: int64

# %%
print(Employee_Dataset["Monthly Income"].unique())
# Out:
# [ 5993  5130  2090  2909  3468  3068  2670  2693  9526  5237  2426  4193
#   2911  2661  2028  9980  3298  2935 15427  3944  4011  3407 11994]

# %% [markdown]
# ## 1.3 Give Me The List Of Top 5 Monthly Income

# %%
Employee_Dataset.sort_values(by="Monthly Income", ascending=False)[["Department","Monthly Income"]].head(10) #chain Methods
# Out:
#               Department  Monthly Income
# 20                 Sales           15427
# 24                   R&D           11994
# 17  Software Development            9980
# 8                    R&D            9526
# 0               Training            5993
# 9   Software Development            5237
# 1                  Sales            5130
# 13  Software Development            4193
# 22           Development            4011
# 21                   R&D            3944

# %% [markdown]
# ## 1.3 Give Me The List Of Least 5 Monthly Income

# %%
Employee_Dataset.sort_values(by="Monthly Income", ascending=True)[["Department","Monthly Income"]].head(10) #chain Methods
# Out:
#               Department  Monthly Income
# 16  Software Development            2028
# 2                    R&D            2090
# 10  Software Development            2426
# 12  Software Development            2426
# 11  Software Development            2426
# 15  Software Development            2661
# 6   Software Development            2670
# 7                    R&D            2693
# 3   Software Development            2909
# 14  Software Development            2911

# %% [markdown]
# ## Chapter 2 - Data Cleaning

# %%
Employee_Dataset
# Out:
#    Employee Name  Age Last Working Day            Department      Education  \
# 0         Jitesh   41       31-12-9999              Training        Masters
# 1         Sanjit   49       31-12-9999                 Sales        Masters
# 2           John   37       31-12-9999                   R&D      Doctorate
# 3         Sandra   33       31-12-9999  Software Development  Undergraduate
# 4          Madhu   27       31-12-9999                   R&D        Masters
# 5         Robert   32       31-12-9999                   R&D        Masters
# 6          Megan   59       31-12-9999  Software Development        Masters
# 7           Matt   30       31-12-9999                   R&D      Doctorate
# 8           Will   38       01-03-2012                   R&D      Doctorate
# 9         George   36       31-12-9999  Software Development        Masters
# 10          Adam   35       31-12-9999  Software Development        Masters
# ...

# %%
Employee_Dataset.dtypes
# Out:
# Employee Name          object
# Age                     int64
# Last Working Day       object
# Department             object
# Education              object
# Gender                 object
# Marital Status         object
# Monthly Income          int64
# Years of Experience     int64
# Percent Salary Hike     int64
# Performance Rating      int64
# dtype: object

# %%
Employee_Dataset["Marital Status"]= Employee_Dataset["Marital Status"].str.replace("Divorced","Single")

# %%
# series

# %%
Employee_Dataset["Performance Rating"] = Employee_Dataset["Performance Rating"].replace({
    3: 3.45,
    4: 4.45
})  #chain of methods

# %%
Employee_Dataset["Performance Rating"]
# Out:
# 0     3.45
# 1     4.45
# 2     3.45
# 3     3.45
# 4     3.45
# 5     3.45
# 6     4.45
# 7     4.45
# 8     4.45
# 9     3.45
# 10    3.45
# 11    3.45
# 12    3.45
# 13    3.45
# 14    3.45
# 15    3.45
# 16    3.45
# 17    3.45
# 18    3.45
# 19    3.45
# 20    3.45
# 21    3.45
# 22    3.45
# 23    4.45
# 24    3.45
# Name: Performance Rating, dtype: float64

# %%
Employee_Dataset["Employee Name"] = Employee_Dataset["Employee Name"].replace({
    "Adam": "hasan"
    
})

# %%
Employee_Dataset["Employee Name"]
# Out:
# 0        Jitesh
# 1        Sanjit
# 2          John
# 3        Sandra
# 4         Madhu
# 5        Robert
# 6         Megan
# 7          Matt
# 8          Will
# 9        George
# 10        hasan
# 11        hasan
# 12        hasan
# 13         Emma
# 14          Vin
# 15      Richard
# 16        Clint
# 17         Kate
# 18       Morgan
# 19          Mel
# 20       Nicole
# 21     Angelina
# 22    Katherine
# 23         Sean
# 24       Stella
# Name: Employee Name, dtype: object

# %%
Employee_Dataset.dtypes
# Out:
# Employee Name           object
# Age                      int64
# Last Working Day        object
# Department              object
# Education               object
# Gender                  object
# Marital Status          object
# Monthly Income           int64
# Years of Experience      int64
# Percent Salary Hike      int64
# Performance Rating     float64
# dtype: object

# %%
Employee_Dataset
# Out:
#    Employee Name  Age Last Working Day            Department      Education  \
# 0         Jitesh   41       31-12-9999              Training        Masters
# 1         Sanjit   49       31-12-9999                 Sales        Masters
# 2           John   37       31-12-9999                   R&D      Doctorate
# 3         Sandra   33       31-12-9999  Software Development  Undergraduate
# 4          Madhu   27       31-12-9999                   R&D        Masters
# 5         Robert   32       31-12-9999                   R&D        Masters
# 6          Megan   59       31-12-9999  Software Development        Masters
# 7           Matt   30       31-12-9999                   R&D      Doctorate
# 8           Will   38       01-03-2012                   R&D      Doctorate
# 9         George   36       31-12-9999  Software Development        Masters
# 10         hasan   35       31-12-9999  Software Development        Masters
# ...

# %%
Employee_Dataset.describe()
# Out:
#             Age  Monthly Income  Years of Experience  Percent Salary Hike  \
# count  25.00000       25.000000            25.000000            25.000000
# mean   35.08000     4674.040000             2.320000            14.760000
# std     8.40595     3427.734474             2.939955             4.075128
# min    22.00000     2028.000000             0.000000            11.000000
# 25%    30.00000     2670.000000             0.000000            12.000000
# 50%    34.00000     3298.000000             1.000000            13.000000
# 75%    37.00000     5130.000000             5.000000            17.000000
# max    59.00000    15427.000000             9.000000            23.000000
#
#        Performance Rating
# count           25.000000
# mean             3.650000
# std              0.408248
# min              3.450000
# 25%              3.450000
# 50%              3.450000
# 75%              3.450000
# max              4.450000

# %% [markdown]
# ## Task
# 1. Find Out The Top 5 Selling Items Individual Revenue It Made
# 2. Total Revenue Of The Top 5 Items Sold
# 3. Find atleast 2 More questions On The Same Dataset

# %% [markdown]
# ## Chapter 3 - Pandas Data Structure
#
# - 1D - Series
# - 2D - DataFrame

# %%
pd.Series(data=[1,2,5.6,"$5.6"])
# Out:
# 0       1
# 1       2
# 2     5.6
# 3    $5.6
# dtype: object

# %%
pd.DataFrame(data={"Names":["Hasan","Abu","Monish","Abdul","Asik"],
                    "Math":[87,89,90,67,3],
                    "Science":[90,98,100,90,99],
                    "Social":[100,70,80,99,100]})
# Out:
#     Names  Math  Science  Social
# 0   Hasan    87       90     100
# 1     Abu    89       98      70
# 2  Monish    90      100      80
# 3   Abdul    67       90      99
# 4    Asik     3       99     100

# %% [markdown]
# ## Task
#
# 1. Create a meaningful Series
# 2. Create a meaningful Dataset using DataFrame with Dict 5 Observation across 6 Features

# %% [markdown]
# ## Chapter 4 - Filtering & Selection & Sorting

# %%
Euro_2012_stats = pd.read_csv("Euro_2012_stats_TEAM.csv")
Euro_2012_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
Euro_2012_stats.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
Filtered_euro_data = Euro_2012_stats[["Team", "Goals","Red Cards","Yellow Cards"]]
Filtered_euro_data
# Out:
#                    Team  Goals  Red Cards  Yellow Cards
# 0               Croatia      4          0             9
# 1        Czech Republic      4          0             7
# 2               Denmark      4          0             4
# 3               England      5          0             5
# 4                France      3          0             6
# 5               Germany     10          0             4
# 6                Greece      5          1             9
# 7                 Italy      6          0            16
# 8           Netherlands      2          0             5
# 9                Poland      2          1             7
# 10             Portugal      6          0            12
# 11  Republic of Ireland      1          1             6
# 12               Russia      5          0             6
# 13                Spain     12          0            11
# 14               Sweden      5          0             7
# 15              Ukraine      2          0             5

# %%
Euro_2012_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# #### 4.1 Top 5 Yellow Cards Team

# %%
Filtered_euro_data.sort_values("Yellow Cards",ascending = False).head()
# Out:
#         Team  Goals  Red Cards  Yellow Cards
# 7      Italy      6          0            16
# 10  Portugal      6          0            12
# 13     Spain     12          0            11
# 0    Croatia      4          0             9
# 6     Greece      5          1             9

# %%
Filtered_euro_data
# Out:
#                    Team  Goals  Red Cards  Yellow Cards
# 0               Croatia      4          0             9
# 1        Czech Republic      4          0             7
# 2               Denmark      4          0             4
# 3               England      5          0             5
# 4                France      3          0             6
# 5               Germany     10          0             4
# 6                Greece      5          1             9
# 7                 Italy      6          0            16
# 8           Netherlands      2          0             5
# 9                Poland      2          1             7
# 10             Portugal      6          0            12
# 11  Republic of Ireland      1          1             6
# 12               Russia      5          0             6
# 13                Spain     12          0            11
# 14               Sweden      5          0             7
# 15              Ukraine      2          0             5

# %% [markdown]
# #### 4.2 List The Teams Which Has Got Red Cards

# %%
Filtered_euro_data[Filtered_euro_data["Red Cards"] == 1]
# Out:
#                    Team  Goals  Red Cards  Yellow Cards
# 6                Greece      5          1             9
# 9                Poland      2          1             7
# 11  Republic of Ireland      1          1             6

# %% [markdown]
# #### 4.3 List teams Which has Got more than 8 Yellow Cards

# %%
Filtered_euro_data[Filtered_euro_data["Yellow Cards"] >=8]
# Out:
#         Team  Goals  Red Cards  Yellow Cards
# 0    Croatia      4          0             9
# 6     Greece      5          1             9
# 7      Italy      6          0            16
# 10  Portugal      6          0            12
# 13     Spain     12          0            11

# %% [markdown]
# ## Task
# 1. Find out 5 new questions along with the Script Answers

# %%
Filtered_euro_data[Filtered_euro_data["Goals"] >=7]
# Out:
#        Team  Goals  Red Cards  Yellow Cards
# 5   Germany     10          0             4
# 13    Spain     12          0            11

# %%
Filtered_euro_data[Filtered_euro_data["Goals"] == 4]
# Out:
#              Team  Goals  Red Cards  Yellow Cards
# 0         Croatia      4          0             9
# 1  Czech Republic      4          0             7
# 2         Denmark      4          0             4

# %% [markdown]
# ## Chapter 5 - How to deal with Missing Values

# %%
proitbridge_emp_data = pd.read_csv("employee_data.csv")
proitbridge_emp_data
# Out:
#     Employee_ID          Name   Age  Gender  Department            Job_Title  \
# 0          1001  Rahul Sharma  28.0    Male          IT         Data Analyst
# 1          1002    Priya Nair  31.0  Female          HR         HR Executive
# 2          1003   Arjun Kumar  29.0    Male     Finance           Accountant
# 3          1004   Sneha Reddy   NaN  Female          IT    Software Engineer
# 4          1005  Vikram Singh  35.0    Male       Sales        Sales Manager
# 5          1006    Aisha Khan  27.0  Female         NaN         Data Analyst
# 6          1007     Rohit Das  30.0    Male          IT       Data Scientist
# 7          1008    Meena Iyer  26.0  Female   Marketing  Marketing Executive
# 8          1009   Karan Patel  32.0    Male     Finance    Financial Analyst
# 9          1010     Divya Rao  29.0  Female          IT    Software Engineer
# 10         1011  Rahul Sharma  28.0    Male          IT         Data Analyst
# ...

# %% [markdown]
# ## Level 1 of Data Cleaning

# %% [markdown]
# ### Always Recommended: I'll call to my client , and check with him if he can give the right data
#
# Incase client is asking us to perform the Data cleaning Operation

# %% [markdown]
# #### Step 1: Remove Duplicate entries/Records

# %%
proitbridge_emp_data.drop_duplicates(inplace = True) #the complete operations will impact the original Dataset

# %%
proitbridge_emp_data
# Out:
#     Employee_ID          Name   Age  Gender  Department            Job_Title  \
# 0          1001  Rahul Sharma  28.0    Male          IT         Data Analyst
# 1          1002    Priya Nair  31.0  Female          HR         HR Executive
# 2          1003   Arjun Kumar  29.0    Male     Finance           Accountant
# 3          1004   Sneha Reddy   NaN  Female          IT    Software Engineer
# 4          1005  Vikram Singh  35.0    Male       Sales        Sales Manager
# 5          1006    Aisha Khan  27.0  Female         NaN         Data Analyst
# 6          1007     Rohit Das  30.0    Male          IT       Data Scientist
# 7          1008    Meena Iyer  26.0  Female   Marketing  Marketing Executive
# 8          1009   Karan Patel  32.0    Male     Finance    Financial Analyst
# 9          1010     Divya Rao  29.0  Female          IT    Software Engineer
# 10         1011  Rahul Sharma  28.0    Male          IT         Data Analyst
# ...

# %%
proitbridge_emp_data.shape
# Out:
# (20, 13)

# %% [markdown]
# ## Step 2: Find Out The Null Entries

# %%
proitbridge_emp_data.isnull().sum()
# Out:
# Employee_ID            0
# Name                   0
# Age                    1
# Gender                 0
# Department             1
# Job_Title              1
# Salary                 1
# Joining_Date           0
# Last_Working_Day      18
# Performance_Rating     0
# Experience_Years       0
# City                   0
# Email                  0
# dtype: int64

# %%
proitbridge_emp_data.dropna(inplace = True)

# %%
proitbridge_emp_data
# Out:
#     Employee_ID          Name   Age Gender Department        Job_Title Salary  \
# 4          1005  Vikram Singh  35.0   Male      Sales    Sales Manager  72000
# 13         1014     Manoj Raj  38.0   Male      Sales  Sales Executive  51000
#
#    Joining_Date Last_Working_Day  Performance_Rating  Experience_Years  \
# 4    2018-11-25       2024-02-01                   4                10
# 13   2017-09-28       2023-12-15                   2                12
#
#           City             Email
# 4       Mumbai  vikram@gmail.com
# 13  Coimbatore   manoj@gmail.com

# %%
proitbridge_emp_data.shape
# Out:
# (2, 13)

# %% [markdown]
# ### Step 3: Record in a Document
#
# - Client gave totally 20 observation out of which 18 entries are removed because those records do not have complete information
#
# ### step 4: Get Approval
# - send this to client and get the approval to proceed for model building or model training

# %%
proitbridge_emp_data.isnull().sum()
# Out:
# Employee_ID           0
# Name                  0
# Age                   0
# Gender                0
# Department            0
# Job_Title             0
# Salary                0
# Joining_Date          0
# Last_Working_Day      0
# Performance_Rating    0
# Experience_Years      0
# City                  0
# Email                 0
# dtype: int64

# %% [markdown]
# ## Level 2 of Data Cleaning

# %%
pd.read_excel() #you can import multiple sheets
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 pd.read_excel() #you can import multiple sheets
#
# TypeError: read_excel() missing 1 required positional argument: 'io'

# %%
pd.read_csv() #you can import multiple sheets if it's in one csv file you need to have separate csv file

# %%
new_employee_data = pd.read_excel("new_employee_data.xlsx",sheet_name = "new_employee_data")
new_employee_data
# Out:
#     Employee_ID          Name   Age  Gender  Department            Job_Title  \
# 0          1001   Pooja Verma  25.0  Female          HR    Software Engineer
# 1          1002   Sneha Reddy  25.0    Male   Marketing  Marketing Executive
# 2          1003    Meena Iyer  25.0  Female     Finance        Sales Manager
# 3          1004  Rohit Sharma  22.0  Female         NaN  Marketing Executive
# 4          1005   Nisha Gupta  35.0    Male     Finance  Marketing Executive
# 5          1006    Divya Nair  22.0  Female          HR           Supervisor
# 6          1007   Deepika Sen   NaN    Male          IT  Marketing Executive
# 7          1008    Aisha Khan  40.0    Male          IT           Supervisor
# 8          1009    Divya Nair  35.0    Male       Sales           Accountant
# 9          1010  Rohit Sharma   NaN    Male          IT        Sales Manager
# 10         1011    Aisha Khan  30.0    Male         NaN    Software Engineer
# ...

# %% [markdown]
# #### Step 1: Drop Duplicates

# %%
new_employee_data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
new_employee_data.drop_duplicates(inplace = True)

# %%
new_employee_data
# Out:
#     Employee_ID          Name   Age  Gender  Department            Job_Title  \
# 0          1001   Pooja Verma  25.0  Female          HR    Software Engineer
# 1          1002   Sneha Reddy  25.0    Male   Marketing  Marketing Executive
# 2          1003    Meena Iyer  25.0  Female     Finance        Sales Manager
# 3          1004  Rohit Sharma  22.0  Female         NaN  Marketing Executive
# 4          1005   Nisha Gupta  35.0    Male     Finance  Marketing Executive
# 5          1006    Divya Nair  22.0  Female          HR           Supervisor
# 6          1007   Deepika Sen   NaN    Male          IT  Marketing Executive
# 7          1008    Aisha Khan  40.0    Male          IT           Supervisor
# 8          1009    Divya Nair  35.0    Male       Sales           Accountant
# 9          1010  Rohit Sharma   NaN    Male          IT        Sales Manager
# 10         1011    Aisha Khan  30.0    Male         NaN    Software Engineer
# ...

# %% [markdown]
# #### Step 2: identify Null Entries

# %%
new_employee_data.isna().sum()
# Out:
# Employee_ID            0
# Name                   0
# Age                    6
# Gender                 0
# Department             7
# Job_Title              5
# Salary                 7
# Joining_Date           0
# Last_Working_Day      27
# Performance_Rating     0
# Experience_Years       0
# City                   0
# Email                  0
# dtype: int64

# %% [markdown]
# #### Step 3: Go For The Best Imputation

# %%
new_employee_data["Department"].unique()
# Out:
# array(['HR', 'Marketing', 'Finance', nan, 'IT', 'Sales', 'Operations'],
#       dtype=object)

# %%
new_employee_data["Department"]
# Out:
# 0             HR
# 1      Marketing
# 2        Finance
# 3            NaN
# 4        Finance
# 5             HR
# 6             IT
# 7             IT
# 8          Sales
# 9             IT
# 10           NaN
# 11           NaN
# 12         Sales
# 13           NaN
# 14         Sales
# 15         Sales
# 16         Sales
# 17            IT
# 18     Marketing
# 19       Finance
# 20         Sales
# 21            HR
# 22           NaN
# 23            HR
# 24         Sales
# 25            HR
# 26            IT
# 27       Finance
# 28         Sales
# 29            HR
# 30    Operations
# 31       Finance
# 32         Sales
# 33           NaN
# 34            HR
# 35         Sales
# 36    Operations
# 37     Marketing
# 38    Operations
# 39     Marketing
# 40    Operations
# 41            HR
# 42    Operations
# 43     Marketing
# 44    Operations
# 45     Marketing
# 46         Sales
# 47       Finance
# 48           NaN
# 49       Finance
# Name: Department, dtype: object

# %%
new_employee_data[new_employee_data["Department"] == "Operations"]
# Out:
#     Employee_ID          Name   Age  Gender  Department            Job_Title  \
# 30         1031    Aisha Khan  35.0  Female  Operations                  NaN
# 36         1037  Rohit Sharma  40.0    Male  Operations    Software Engineer
# 38         1039    Divya Nair   NaN    Male  Operations         Data Analyst
# 40         1041    Meena Iyer  35.0  Female  Operations         HR Executive
# 42         1043  Rohit Sharma  40.0  Female  Operations                  NaN
# 44         1045    Ajay Kumar  30.0    Male  Operations  Marketing Executive
#
#        Salary Joining_Date Last_Working_Day  Performance_Rating  \
# 30      55000   2021-05-12       2024-02-01                   3
# 36  85000 INR   2020/08/15              NaN                   2
# 38      65000   2021-05-12              NaN                   2
# 40      55000   2018-11-25              NaN                   3
# 42      55000   2022-01-10              NaN                   4
# ...

# %%
new_employee_data[new_employee_data["Department"] == "Sales"]
# Out:
#     Employee_ID          Name   Age  Gender Department          Job_Title  \
# 8          1009    Divya Nair  35.0    Male      Sales         Accountant
# 12         1013   Pooja Verma  22.0    Male      Sales       Data Analyst
# 14         1015   Deepika Sen  35.0    Male      Sales  Software Engineer
# 15         1016  Priya Sharma  25.0  Female      Sales  Software Engineer
# 16         1017  Rohit Sharma  22.0    Male      Sales       HR Executive
# 20         1021    Ajay Kumar  28.0    Male      Sales       HR Executive
# 24         1025  Mohammed Ali  22.0  Female      Sales                NaN
# 28         1029    Meena Iyer  40.0  Female      Sales         Accountant
# 32         1033  Vikram Singh  30.0    Male      Sales       HR Executive
# 35         1036   Nisha Gupta   NaN  Female      Sales      Sales Manager
# 46         1047   Karthik Raj  30.0    Male      Sales  Software Engineer
#
#        Salary Joining_Date Last_Working_Day  Performance_Rating  \
# ...

# %%
new_employee_data[new_employee_data["Department"] == "IT"]
# Out:
#     Employee_ID          Name   Age  Gender Department            Job_Title  \
# 6          1007   Deepika Sen   NaN    Male         IT  Marketing Executive
# 7          1008    Aisha Khan  40.0    Male         IT           Supervisor
# 9          1010  Rohit Sharma   NaN    Male         IT        Sales Manager
# 17         1018    Aisha Khan   NaN  Female         IT         Data Analyst
# 26         1027  Vikram Singh  30.0    Male         IT         Data Analyst
#
#        Salary Joining_Date Last_Working_Day  Performance_Rating  \
# 6   85000 INR   15-07-2019       2024-02-01                   4
# 7         NaN   2018-11-25              NaN                   4
# 9       55000   2022-01-10       2024-02-01                   4
# 17      72000   2021-05-12       2023-12-15                   4
# 26      72000   2021-05-12       2023-12-15                   4
#
#     Experience_Years       City               Email
# 6                  7    Chennai          wrongemail
# ...

# %%
new_employee_data[new_employee_data["Department"] == "Finance"]
# Out:
#     Employee_ID          Name   Age  Gender Department            Job_Title  \
# 2          1003    Meena Iyer  25.0  Female    Finance        Sales Manager
# 4          1005   Nisha Gupta  35.0    Male    Finance  Marketing Executive
# 19         1020    Arun Kumar  40.0  Female    Finance           Supervisor
# 27         1028  Priya Sharma  40.0  Female    Finance                  NaN
# 31         1032  Priya Sharma  30.0    Male    Finance        Sales Manager
# 47         1048   Pooja Verma  22.0    Male    Finance         HR Executive
# 49         1050    Divya Nair  25.0  Female    Finance  Marketing Executive
#
#            Salary Joining_Date Last_Working_Day  Performance_Rating  \
# 2           65000   wrong_date       2024-02-01                   3
# 4           65000   2021-05-12       2023-12-15                   5
# 19  not available   2022-01-10       2024-02-01                   3
# 27          65000   2018-11-25       2024-02-01                   3
# ...

# %%
new_employee_data[new_employee_data["Department"] == "Marketing"]
# Out:
#     Employee_ID         Name   Age  Gender Department            Job_Title  \
# 1          1002  Sneha Reddy  25.0    Male  Marketing  Marketing Executive
# 18         1019  Nisha Gupta  22.0  Female  Marketing        Sales Manager
# 37         1038  Sneha Reddy  25.0  Female  Marketing         HR Executive
# 39         1040  Sneha Reddy  28.0    Male  Marketing           Accountant
# 43         1044   Meena Iyer  40.0  Female  Marketing  Marketing Executive
# 45         1046   Divya Nair  40.0    Male  Marketing         Data Analyst
#
#            Salary Joining_Date Last_Working_Day  Performance_Rating  \
# 1   not available   2018-11-25              NaN                   5
# 18          45000   2021-05-12              NaN                   4
# 37          55000   2018-11-25              NaN                   5
# 39      85000 INR   2020/08/15       2024-02-01                   4
# 43          55000   2022-01-10              NaN                   3
# ...

# %%
new_employee_data[new_employee_data["Department"] == "HR"]
# Out:
#     Employee_ID          Name   Age  Gender Department          Job_Title  \
# 0          1001   Pooja Verma  25.0  Female         HR  Software Engineer
# 5          1006    Divya Nair  22.0  Female         HR         Supervisor
# 21         1022    Divya Nair  35.0  Female         HR         Accountant
# 23         1024  Priya Sharma   NaN    Male         HR         Accountant
# 25         1026    Ajay Kumar  35.0    Male         HR                NaN
# 29         1030  Rohit Sharma  22.0    Male         HR         Accountant
# 34         1035   Pooja Verma  22.0  Female         HR       HR Executive
# 41         1042    Meena Iyer  25.0    Male         HR       HR Executive
#
#        Salary Joining_Date Last_Working_Day  Performance_Rating  \
# 0         NaN   2022-01-10       2024-02-01                   2
# 5         NaN   2018-11-25              NaN                   5
# 21  85000 INR   15-07-2019              NaN                   3
# ...

# %% [markdown]
# ### Task
#
# 1. Impute The relevent Values in the Salary Column Wharever it is NaN,based on Department Filtering

# %%
new_employee_data[new_employee_data["Department"] == "Operations"]
# Out:
#     Employee_ID          Name   Age  Gender  Department            Job_Title  \
# 30         1031    Aisha Khan  35.0  Female  Operations                  NaN
# 36         1037  Rohit Sharma  40.0    Male  Operations    Software Engineer
# 38         1039    Divya Nair   NaN    Male  Operations         Data Analyst
# 40         1041    Meena Iyer  35.0  Female  Operations         HR Executive
# 42         1043  Rohit Sharma  40.0  Female  Operations                  NaN
# 44         1045    Ajay Kumar  30.0    Male  Operations  Marketing Executive
#
#        Salary Joining_Date Last_Working_Day  Performance_Rating  \
# 30      55000   2021-05-12       2024-02-01                   3
# 36  85000 INR   2020/08/15              NaN                   2
# 38      65000   2021-05-12              NaN                   2
# 40      55000   2018-11-25              NaN                   3
# 42      55000   2022-01-10              NaN                   4
# ...

# %%
new_employee_data[(new_employee_data["Department"] == "Operations") & (new_employee_data["Job_Title"].isna())]
# Out:
#     Employee_ID          Name   Age  Gender  Department Job_Title Salary  \
# 30         1031    Aisha Khan  35.0  Female  Operations       NaN  55000
# 42         1043  Rohit Sharma  40.0  Female  Operations       NaN  55000
#
#    Joining_Date Last_Working_Day  Performance_Rating  Experience_Years  \
# 30   2021-05-12       2024-02-01                   3                15
# 42   2022-01-10              NaN                   4                 1
#
#          City               Email
# 30      Delhi  employee@gmail.com
# 42  Bangalore  worker@company.com
